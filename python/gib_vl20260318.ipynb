# %%
# Demo file for working with univariate data
# live entstanden in der Vorlesung GIB Mathematik2, 18.03.2026
#
# copyright: Barbara Staehle, HTWG Konstanz
# bstaehle@htwg-konstanz.de

# import library we use for plotting and calculating
import matplotlib.pyplot as plt
import numpy as np

# %%
# body length in cm of students attending the lecture
x = [170, 161, 173, 176, 172, 189, 167, 173]
print(x)
# Out:
# [170, 161, 173, 176, 172, 189, 167, 173]

# %%
# plot koerpergroessen
plt.figure()
# this results in Teilnehmernummern 0-7
# plt.plot(x, marker='*', markersize=5, linestyle='none',linewidth=5,color='green')
# range(1,len(x)+1) cares for having 1-8 on the x-axis
plt.plot(range(1,len(x)+1),x, marker='*', markersize=5, linestyle='none',linewidth=5,color='green')
# label your axis!!
plt.xlabel('Teilnehmernummer')
plt.ylabel('Körpergröße [cm]')
plt.grid(True)

# %%
# count how often each value occurs
values, counts = np.unique(x,return_counts=True)
print(f'Werte in der Liste: {values}')
print(f'Absolute Häufigkeiten: {counts}')
# Out:
# Werte in der Liste: [161 167 170 172 173 176 189]
# Absolute Häufigkeiten: [1 1 1 1 2 1 1]

# %%
# show as bar plot
plt.bar(values,counts)
plt.grid(True)
plt.xlabel('Körpergröße [cm]')
plt.ylabel('absolute Häufigkeit')
plt.yticks([0,1,2])
# Out:
# ([<matplotlib.axis.YTick at 0x256a51a2d50>,
#   <matplotlib.axis.YTick at 0x256a5162210>,
#   <matplotlib.axis.YTick at 0x256a5162990>],
#  [Text(0, 0, '0'), Text(0, 1, '1'), Text(0, 2, '2')])

# %%
# show as stem plot
plt.stem(values,counts)
plt.grid(True)
plt.xlabel('Körpergröße [cm]')
plt.ylabel('absolute Häufigkeit')
plt.yticks([0.1,2])
# Out:
# ([<matplotlib.axis.YTick at 0x256a4ebe990>,
#   <matplotlib.axis.YTick at 0x256a51dd090>],
#  [Text(0, 0.1, '0.1'), Text(0, 2.0, '2.0')])

# %%
# WRONG graphical representation!! 
plt.plot(values,counts,color='r')
plt.grid(True)
plt.xlabel('Körpergröße [cm]')
plt.ylabel('absolute Häufigkeit')
plt.yticks([0,1,2,3])
plt.ylim(0,3)
plt.title('Achtung, so bitte auf keinen Fall darstellen!')
# Out:
# Text(0.5, 1.0, 'Achtung, so bitte auf keinen Fall darstellen!')

# %%
# show graphically via dots only (do not connect)
plt.plot(values,counts,linestyle='none',marker='*')
plt.grid(True)
plt.xlabel('Körpergröße [cm]')
plt.ylabel('absolute Häufigkeit')
plt.yticks([0,1,2,3])
plt.ylim(0,3)
# Out:
# (0.0, 3.0)
